# %% [markdown]
# # Data Explorer example
#
# This notebook emits a Data Explorer MIME payload from a real Polars dataframe.

# %%
import polars as pl
from data_wrangler_runtime.notebook import show

df = pl.read_csv("fixtures/sample.csv")
show(df, label="sample.csv")
